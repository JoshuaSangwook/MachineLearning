# %%
import os

import pandas as pd
import numpy as np

from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import TomekLinks
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.metrics import geometric_mean_score

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from statsmodels.discrete.discrete_model import Logit
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %matplotlib notebook
# %seaborn notebook
# Out:
# ERROR:root:Line magic function `%seaborn` not found.

# %%
dir = "/Users/1002516/Downloads/2일차/mini project/loan_practice"
DF = pd.read_csv(dir+"/loan_data.csv")

# %%
DF
print(DF.shape)
print(DF.dtypes)
print(DF.describe(include = 'all'))
# Out:
# (43386, 23)
# AGE                int64
# TOT_LOAN           int64
# TOT_LOAN_CRD       int64
# LOAN_BNK           int64
# LOAN_CPT           int64
# CRDT_CNT           int64
# GUARN_CNT          int64
# INCOME             int64
# LOAN_CRD_CNT       int64
# LATE_RATE          int64
# LATE_RATE_1Y       int64
# INS_MON_MAX      float64
# CANCEL_CNT_1Y      int64
# CALL_TIME        float64
# TEL_COST_MON       int64
# MOBILE_PRICE       int64
# SUSP_DAY           int64
# LATE_TEL           int64
# COMB_COMM          int64
# SEX               object
# PAY_METHOD        object
# JOB               object
# TARGET             int64
# dtype: object
#                  AGE      TOT_LOAN  TOT_LOAN_CRD      LOAN_BNK      LOAN_CPT  \
# count   43386.000000  43386.000000  43386.000000  43386.000000  43386.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       46.250980     82.019407     32.829622     49.324897      4.288641
# std         9.693741    126.702976     83.419760     92.443944     12.660968
# min        20.000000      0.000000      0.000000      0.000000      0.000000
# 25%        40.000000     12.000000      0.000000      0.000000      0.000000
# 50%        45.000000     36.000000      9.000000      9.000000      0.000000
# 75%        55.000000    102.000000     27.000000     60.000000      3.000000
# max        70.000000    994.000000    994.000000    944.000000    301.000000
#
#             CRDT_CNT     GUARN_CNT        INCOME  LOAN_CRD_CNT     LATE_RATE  \
# count   43386.000000  43386.000000  43386.000000  43386.000000  43386.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        3.004264      0.098695   2778.629051      0.163855      8.216406
# std         1.842478      0.529664   2470.097227      0.617522     12.120840
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         2.000000      0.000000      0.000000      0.000000      0.000000
# 50%         3.000000      0.000000   3600.000000      0.000000      3.000000
# 75%         4.000000      0.000000   4700.000000      0.000000     11.000000
# max        11.000000     10.000000  10000.000000     11.000000    100.000000
#
#             ...          CALL_TIME  TEL_COST_MON  MOBILE_PRICE      SUSP_DAY  \
# count       ...       43386.000000  43386.000000  43386.000000  43386.000000
# unique      ...                NaN           NaN           NaN           NaN
# top         ...                NaN           NaN           NaN           NaN
# freq        ...                NaN           NaN           NaN           NaN
# mean        ...           2.098970     75.477804    534.423547     18.433320
# std         ...          15.364253     62.311464    382.237230    133.523351
# min         ...           0.000000      0.000000      0.000000      0.000000
# 25%         ...           0.430000     40.000000      0.000000      0.000000
# 50%         ...           0.990000     60.000000    700.000000      0.000000
# 75%         ...           1.887500     80.000000    900.000000      0.000000
# max         ...        1520.000000    950.000000   1200.000000   2700.000000
#
#             LATE_TEL     COMB_COMM    SEX  PAY_METHOD    JOB        TARGET
# count   43386.000000  43386.000000  43386       43386  43386  43386.000000
# unique           NaN           NaN      2           4      4           NaN
# top              NaN           NaN      F           C      B           NaN
# freq             NaN           NaN  23712       25139  20532           NaN
# mean       13.757664      0.425068    NaN         NaN    NaN      0.095238
# std        53.272289      0.494359    NaN         NaN    NaN      0.293547
# min         0.000000      0.000000    NaN         NaN    NaN      0.000000
# 25%         0.000000      0.000000    NaN         NaN    NaN      0.000000
# 50%         0.000000      0.000000    NaN         NaN    NaN      0.000000
# 75%         0.000000      1.000000    NaN         NaN    NaN      0.000000
# max      1200.000000      1.000000    NaN         NaN    NaN      1.000000
#
# [11 rows x 23 columns]

# %%
sns.set(context="paper", font="monospace")
corr = DF.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr, vmin=-1.0, vmax=1.0, square=True,
            cmap=sns.diverging_palette(240, 10, as_cmap=True))
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
select_columns = ['LOAN_BNK', 'TOT_LOAN', 'TOT_LOAN_CRD', 'TARGET']
sns.pairplot(DF[select_columns], hue='TARGET', size=3, plot_kws={"s": 8})
# Out:
# <img src="data:image/png;base64,..." width="2493">

# %%
sns.countplot(x='TARGET', data=DF)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.boxplot(y='LOAN_BNK', x='TARGET', data=DF, showmeans=True)
sns.boxplot(y='TOT_LOAN', x='TARGET', data=DF, showmeans=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y = DF['TARGET']
X = DF.drop('TARGET', 1)

# %%
X = pd.get_dummies(X)

# %%
X.describe()
# Out:
#                 AGE      TOT_LOAN  TOT_LOAN_CRD      LOAN_BNK      LOAN_CPT  \
# count  43386.000000  43386.000000  43386.000000  43386.000000  43386.000000
# mean      46.250980     82.019407     32.829622     49.324897      4.288641
# std        9.693741    126.702976     83.419760     92.443944     12.660968
# min       20.000000      0.000000      0.000000      0.000000      0.000000
# 25%       40.000000     12.000000      0.000000      0.000000      0.000000
# 50%       45.000000     36.000000      9.000000      9.000000      0.000000
# 75%       55.000000    102.000000     27.000000     60.000000      3.000000
# max       70.000000    994.000000    994.000000    944.000000    301.000000
#
#            CRDT_CNT     GUARN_CNT        INCOME  LOAN_CRD_CNT     LATE_RATE  \
# count  43386.000000  43386.000000  43386.000000  43386.000000  43386.000000
# mean       3.004264      0.098695   2778.629051      0.163855      8.216406
# std        1.842478      0.529664   2470.097227      0.617522     12.120840
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        3.000000      0.000000   3600.000000      0.000000      3.000000
# 75%        4.000000      0.000000   4700.000000      0.000000     11.000000
# max       11.000000     10.000000  10000.000000     11.000000    100.000000
#
#            ...              SEX_F         SEX_M  PAY_METHOD_A  PAY_METHOD_B  \
# count      ...       43386.000000  43386.000000  43386.000000  43386.000000
# mean       ...           0.546536      0.453464      0.058706      0.321717
# std        ...           0.497835      0.497835      0.235076      0.467140
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.000000      0.000000      0.000000      0.000000
# 50%        ...           1.000000      0.000000      0.000000      0.000000
# 75%        ...           1.000000      1.000000      0.000000      1.000000
# max        ...           1.000000      1.000000      1.000000      1.000000
#
#        PAY_METHOD_C  PAY_METHOD_D         JOB_A         JOB_B         JOB_C  \
# count  43386.000000  43386.000000  43386.000000  43386.000000  43386.000000
# mean       0.579427      0.040151      0.078850      0.473240      0.359678
# std        0.493657      0.196316      0.269508      0.499289      0.479912
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        1.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      0.000000      0.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#               JOB_D
# count  43386.000000
# mean       0.088231
# std        0.283634
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 29 columns]

# %%
X = X.drop(['SEX_M','JOB_A','PAY_METHOD_A'], axis=1)
columns = X.columns.tolist()
print(columns)
# Out:
# ['AGE', 'TOT_LOAN', 'TOT_LOAN_CRD', 'LOAN_BNK', 'LOAN_CPT', 'CRDT_CNT', 'GUARN_CNT', 'INCOME', 'LOAN_CRD_CNT', 'LATE_RATE', 'LATE_RATE_1Y', 'INS_MON_MAX', 'CANCEL_CNT_1Y', 'CALL_TIME', 'TEL_COST_MON', 'MOBILE_PRICE', 'SUSP_DAY', 'LATE_TEL', 'COMB_COMM', 'SEX_F', 'PAY_METHOD_B', 'PAY_METHOD_C', 'PAY_METHOD_D', 'JOB_B', 'JOB_C', 'JOB_D']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=111,
                                                    stratify=y)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_simple, y_simple = X_train.copy(), y_train.copy()

del X_train
del y_train

# %%
rus = RandomUnderSampler()
X_rus, y_rus= rus.fit_sample(X_simple, y_simple)

# %%
tl = TomekLinks()
X_tl, y_tl = tl.fit_sample(X_simple, y_simple)

# %%
sm = SMOTE(k_neighbors=5, kind='regular')
X_sm, y_sm = sm.fit_sample(X_simple, y_simple)

# %%
dataset_names = ['Simple', 'Random Under', 'Tomek', 'SMOTE']
datasets = [(X_simple, y_simple), (X_rus, y_rus), (X_tl, y_tl), (X_sm, y_sm)]

# %%
for ds_name, ds in zip(dataset_names, datasets):
    X_train, y_train = ds
    
    # Decision Tree
    dt = DecisionTreeClassifier()
    dt.fit(X_train, y_train)
    y_pred = dt.predict(X_test)
    score = geometric_mean_score(y_test, y_pred)
    score = round(score, 3)
    print("{} Dataset with Decision Tree: {}".format(ds_name, score))

    
    # Logistic Regression
    logit = Logit(endog=y_train, exog=X_train)
    result = logit.fit(maxiter=1000, disp=0)
    y_pred = logit.predict(params=result.params, exog=X_test).round()
    score = geometric_mean_score(y_test, y_pred)
    score = round(score, 3)
    print("{} Dataset with Logistic Regression: {}".format(ds_name, score))
    
    # Random Forest
    rf = RandomForestClassifier(n_estimators=200)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    score = geometric_mean_score(y_test, y_pred)
    score = round(score, 3)
    print("{} Dataset with Random Forest: {}".format(ds_name, score))
# Out:
# Simple Dataset with Decision Tree: 0.601
# Simple Dataset with Logistic Regression: 0.476
# Simple Dataset with Random Forest: 0.538
# Random Under Dataset with Decision Tree: 0.733
# Random Under Dataset with Logistic Regression: 0.779
# Random Under Dataset with Random Forest: 0.817
# Tomek Dataset with Decision Tree: 0.602
# Tomek Dataset with Logistic Regression: 0.504
# Tomek Dataset with Random Forest: 0.564
# SMOTE Dataset with Decision Tree: 0.631
# SMOTE Dataset with Logistic Regression: 0.78
# SMOTE Dataset with Random Forest: 0.657

# %%
from numpy import nanmean
import scipy.stats
logit = Logit(endog=y_rus, exog=X_rus)
result = logit.fit(maxiter=1000, disp=0)
#result.summary()
print(result.summary)
# Out:
# <bound method BinaryResults.summary of <statsmodels.discrete.discrete_model.LogitResults object at 0x1a242135f8>>
# array([  2.47125068e-009,   3.61048567e-004,   5.71542959e-004,
#          1.69011151e-013,   5.42585117e-025,   1.58056684e-125,
#          1.45249202e-004,   5.82164777e-007,   3.44123997e-001,
#          3.46548598e-002,   4.51676527e-022,   5.75377970e-001,
#          3.45174511e-004,   4.80105485e-001,   2.65848628e-004,
#          6.91089259e-006,   1.12261890e-004,   1.54245415e-030,
#          6.44227002e-001,   3.78556846e-003,   1.94754709e-038,
#          6.46846934e-029,   1.82129714e-001,   1.66056076e-021,
#          1.16683271e-012,   4.14067253e-013])

# %%
pval = result.pvalues
coef = result.params

# %%
imp_index = np.where(pval < 0.05)
columns = np.array(columns)

# %%
imp_pval = pval[imp_index]
imp_coef = coef[imp_index]
imp_vars = columns[imp_index]

# %%
plt.figure(figsize=(8,8))
plt.barh(range(len(imp_vars)), imp_coef, color='r')
plt.yticks(range(len(imp_vars)), imp_vars)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
